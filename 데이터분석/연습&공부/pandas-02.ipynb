# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/seoul-opengov/opengov/master/expense_list2021/202112_expense_list.csv '
seoul_exp_01 =pd.read_csv(url)
seoul_exp_01
# Out:
#             nid                                              title  \
# 0      25019637           2021년 12월 사업소 중부공원녹지사업소 시설과 업무추진비 - 부서운영
# 1      25029139                2021년 12월 사업소 은평병원 약제과 업무추진비 - 부서운영
# 2      25029139                2021년 12월 사업소 은평병원 약제과 업무추진비 - 부서운영
# 3      25029139                2021년 12월 사업소 은평병원 약제과 업무추진비 - 부서운영
# 4      25029139                2021년 12월 사업소 은평병원 약제과 업무추진비 - 부서운영
# ...         ...                                                ...
# 10339  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 10340  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 10341  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 10342  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 10343  25116134  2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
#
#                                                url dept_nm_lvl_1  \
# 0      http://opengov.seoul.go.kr/expense/25019637           사업소
# ...

# %%
mem01 = pd.DataFrame()
mem01 = pd.DataFrame([
    [70, 80, 90],
    [90, 80, 80],
])
mem01.index = ["홍", "김"]
mem01.columns = ["언어", "수학", "과학"]
mem01
# Out:
#    언어  수학  과학
# 홍  70  80  90
# 김  90  80  80

# %%
mem01.plot()  # x 증가에 따른 y의 변화 ( 기준은 x )
# Out:
# <AxesSubplot:>
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54861 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50616 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50612 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 54617 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
mem01.T
# Out:
#      홍   김
# 언어  70  90
# 수학  80  80
# 과학  90  80

# %% [markdown]
# ### df[ 칼럼명 ] 열추출.인덱싱
# ### df[ [칼럼명, 칼럼명..] ] 열추출.팬시인덱싱
# ### df[ 인덱스 : 인덱스 ] 행추출.슬라이싱
#
# ### df.loc[ 행인덱스 ] 행추출
# ### df.loc[ 행인덱스, 칼럼명] 값 1개추출
# ### df.loc[ : , 칼럼명] 칼럼추출

# %%
seoul_exp_01['title']
# Out:
# 0                 2021년 12월 사업소 중부공원녹지사업소 시설과 업무추진비 - 부서운영
# 1                      2021년 12월 사업소 은평병원 약제과 업무추진비 - 부서운영
# 2                      2021년 12월 사업소 은평병원 약제과 업무추진비 - 부서운영
# 3                      2021년 12월 사업소 은평병원 약제과 업무추진비 - 부서운영
# 4                      2021년 12월 사업소 은평병원 약제과 업무추진비 - 부서운영
#                                ...
# 10339    2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 10340    2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 10341    2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 10342    2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# 10343    2021년 12월 사업소 상수도사업본부 뚝도아리수정수센터 업무추진비 - 기관운영 시...
# Name: title, Length: 10344, dtype: object

# %%
print(seoul_exp_01['dept_nm_lvl_1'].unique())
print(seoul_exp_01['dept_nm_lvl_1'].shape)
# Out:
# ['사업소' '소방재난본부(소방서)' '서울시본청' '의회사무처']
# (10344,)

# %%
seoul_exp_01['dept_nm_lvl_5'].unique().shape
# Out:
# (11,)

# %%
seoul_exp_01.columns
# Out:
# Index(['nid', 'title', 'url', 'dept_nm_lvl_1', 'dept_nm_lvl_2',
#        'dept_nm_lvl_3', 'dept_nm_lvl_4', 'dept_nm_lvl_5', 'exec_yr',
#        'exec_month', 'expense_budget', 'expense_execution', 'category',
#        'dept_nm_full', 'exec_dt', 'exec_loc', 'exec_purpose', 'target_nm',
#        'payment_method', 'exec_amount'],
#       dtype='object')

# %%
print(seoul_exp_01['exec_yr'].unique())
seoul_exp_01[['exec_dt', 'exec_loc', 'exec_amount']]
# Out:
# [2021]
#                 exec_dt                 exec_loc  exec_amount
# 0      2021-12-17 11:00       ㈜그린주의(중량구 봉화산로123)       347900
# 1      2021-12-23 11:18    오도르아뜰리에(은평구 서오릉로 177)        30000
# 2      2021-12-20 14:50  행복한베이커리&카페(은평구 백련산로 90)        30000
# 3      2021-12-20 14:46          키지아(은평구 백련산로4길)        26150
# 4      2021-12-20 12:40  수빈떡갈비(서대문구 연희로25길 31-3)        89000
# ...                 ...                      ...          ...
# 10339  2021-12-21 19:44      고기사람(서대문구 충정로4길 26)        97000
# 10340  2021-12-07 11:57       장수숯불갈비(성동구 성덕정길40)       120000
# 10341  2021-12-02 12:07       장수숯불갈비(성동구 성덕정길39)       116000
# 10342  2021-12-28 16:48         현대마트(성동구 성덕정길29)       113180
# 10343  2021-12-28 10:15          서울시청매점(중구 덕수궁길)        84000
#
# [10344 rows x 3 columns]

# %%
seoul_exp_01[10:20]
# Out:
#          nid                                           title  \
# 10  25040705  2021년 12월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 전체
# 11  25040705  2021년 12월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 전체
# 12  25040705  2021년 12월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 전체
# 13  25040705  2021년 12월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 전체
# 14  25040705  2021년 12월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 전체
# 15  25040705  2021년 12월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 전체
# 16  25040705  2021년 12월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 전체
# 17  25040705  2021년 12월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 전체
# 18  25040705  2021년 12월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 전체
# 19  25040705  2021년 12월 사업소 상수도사업본부 남부수도사업소 행정지원과 업무추진비 - 전체
#
#                                             url dept_nm_lvl_1 dept_nm_lvl_2  \
# 10  http://opengov.seoul.go.kr/expense/25040705           사업소       상수도사업본부
# 11  http://opengov.seoul.go.kr/expense/25040705           사업소       상수도사업본부
# ...

# %%
b1 = seoul_exp_01['dept_nm_lvl_1'] == '서울시본청'
b1
se1 = seoul_exp_01[b1]   # True에 해당하는 행만 추출!!!!
se1['dept_nm_lvl_1'].unique()    # 서울시본청만 뽑았으니깐 당연한 거다!
# Out:
# array(['서울시본청'], dtype=object)

# %%
mem01 = mem01.rename(columns={"언어":"영어"})


mem01
# Out:
#    영어  수학  과학
# 홍  70  80  90
# 김  90  80  80

# %%
mem01.rename(columns={"영어":"영어2"}, inplace = True)  # inplace는 원본 데이터를 바꿈. 그래서 return이 없음.
mem01
# Out:
#    영어2  수학  과학
# 홍   70  80  90
# 김   90  80  80

# %%
seoul_apt = pd.read_csv("./아파트(매매)__실거래가_20220401113837.csv", encoding="EUC-KR", skiprows=15, thousands=",")
seoul_apt  
# ./는 상대경로
# skiprows는 로우를 스킵한다, 즉 csv에서 설명하는목록을 skip해야지 에러가 안남.
# thousands는 object로 천자리에 comma(,)가 있어서 문제가 되니깐 thousands=","를 하면 type이 object에서 int로 바뀜.!!!

# 외국의 경우는 tsv( tap으로 구분 ) 데이터도 있다.
# Out:
#                  시군구      번지     본번    부번             단지명  전용면적(㎡)    계약년월  \
# 0      서울특별시 강남구 개포동   655-2  655.0   2.0  개포2차현대아파트(220)    77.75  202104
# 1      서울특별시 강남구 개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97  202105
# 2      서울특별시 강남구 개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97  202108
# 3      서울특별시 강남구 개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97  202109
# 4      서울특별시 강남구 개포동   658-1  658.0   1.0  개포6차우성아파트1동~8동    79.97  202112
# ...              ...     ...    ...   ...             ...      ...     ...
# 32134  서울특별시 중랑구 중화동     450  450.0   0.0  한신아파트(103~109)    59.76  202110
# 32135  서울특별시 중랑구 중화동  274-51  274.0  51.0         한영(101)    84.69  202111
# 32136  서울특별시 중랑구 중화동  274-75  274.0  75.0         한영(102)    72.22  202105
# 32137  서울특별시 중랑구 중화동  274-76  274.0  76.0         한영(103)    58.46  202107
# 32138  서울특별시 중랑구 중화동  274-76  274.0  76.0         한영(103)   104.93  202108
#
# ...

# %%
seoul_apt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32139 entries, 0 to 32138
# Data columns (total 15 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   시군구       32139 non-null  object
#  1   번지        32127 non-null  object
#  2   본번        32135 non-null  float64
#  3   부번        32135 non-null  float64
#  4   단지명       32139 non-null  object
#  5   전용면적(㎡)   32139 non-null  float64
#  6   계약년월      32139 non-null  int64
#  7   계약일       32139 non-null  int64
#  8   거래금액(만원)  32139 non-null  int64
#  9   층         32139 non-null  int64
#  10  건축년도      32139 non-null  int64
#  11  도로명       32139 non-null  object
#  12  해제사유발생일   964 non-null    float64
#  13  거래유형      32139 non-null  object
#  14  중개사소재지    32139 non-null  object
# dtypes: float64(4), int64(5), object(6)
# memory usage: 3.7+ MB

# %%
seoul_apt['거래금액(만원)']
# Out:
# 0        174,000
# 1        195,000
# 2        200,000
# 3        220,000
# 4        215,000
#           ...
# 32134     83,200
# 32135     50,000
# 32136     49,500
# 32137     30,000
# 32138     61,500
# Name: 거래금액(만원), Length: 32139, dtype: object

# %%
import seaborn as sns  # 차트그리는 api, 시각화에서 나옴.

titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.describe()  #문자열 데이터는 빠져있다.
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
titanic.describe(include="object")
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
print(titanic["sex"].value_counts())
print(titanic["embarked"].value_counts())
print(titanic["embark_town"].value_counts())
# Out:
# male      577
# female    314
# Name: sex, dtype: int64
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64
# Southampton    644
# Cherbourg      168
# Queenstown      77
# Name: embark_town, dtype: int64

# %%
seoul_apt.sort_values(by="거래금액(만원)")
# Out:
#                  시군구      번지     본번    부번    단지명   전용면적(㎡)    계약년월  계약일  \
# 10800  서울특별시 노원구 공릉동   395-7  395.0   7.0  진명비베레   12.5172  202105   13
# 9587   서울특별시 구로구 오류동   34-13   34.0  13.0    썬앤빌   14.0640  202104   17
# 9595   서울특별시 구로구 오류동   34-13   34.0  13.0    썬앤빌   14.0640  202108   18
# 7717   서울특별시 광진구 화양동  110-37  110.0  37.0   화양타워   15.1800  202104   19
# 9601   서울특별시 구로구 오류동   34-13   34.0  13.0    썬앤빌   14.0640  202202    9
# ...              ...     ...    ...   ...    ...       ...     ...  ...
# 1582   서울특별시 강남구 청담동     129  129.0   0.0  PH129  273.9600  202107    7
# 28692  서울특별시 용산구 한남동     410  410.0   0.0  파르크한남  268.6700  202109    9
# 28693  서울특별시 용산구 한남동     410  410.0   0.0  파르크한남  268.9500  202111   24
# 28694  서울특별시 용산구 한남동     410  410.0   0.0  파르크한남  268.6700  202111   26
# 28695  서울특별시 용산구 한남동     410  410.0   0.0  파르크한남  268.9500  202112   13
#
#        거래금액(만원)   층  건축년도          도로명  해제사유발생일  거래유형  중개사소재지
# ...

# %%
seoul_apt["해제사유발생일"].notna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32134    False
# 32135    False
# 32136    False
# 32137    False
# 32138    False
# Name: 해제사유발생일, Length: 32139, dtype: bool

# %%
seoul_apt[seoul_apt["해제사유발생일"].notnull()].sort_values(by="거래금액(만원)")
# Out:
#                    시군구       번지     본번     부번           단지명  전용면적(㎡)    계약년월  \
# 27532   서울특별시 영등포구 신길동   261-22  261.0   22.0       신길레전드힐스   13.740  202108
# 29166    서울특별시 은평구 대조동     4-12    4.0   12.0         제이타워1   12.230  202104
# 8621     서울특별시 구로구 구로동     44-5   44.0    5.0     비즈트위트레인보우   15.170  202106
# 14390     서울특별시 도봉구 창동        7    7.0    0.0          월가타워   13.090  202107
# 2059      서울특별시 강동구 길동    387-5  387.0    5.0  청광플러스원(큐브1차)   17.075  202112
# ...                ...      ...    ...    ...           ...      ...     ...
# 28700    서울특별시 용산구 한남동      810  810.0    0.0          한남더힐  235.312  202105
# 21303  서울특별시 성동구 성수동1가  685-696  685.0  696.0        갤러리아포레  241.630  202106
# 28712    서울특별시 용산구 한남동      810  810.0    0.0          한남더힐  208.478  202109
# 1611     서울특별시 강남구 청담동   129-16  129.0   16.0    상지리츠빌카일룸3차  265.470  202105
# 1610     서울특별시 강남구 청담동   129-16  129.0   16.0    상지리츠빌카일룸3차  265.470  202105
#
# ...

# %%
seoul_apt.sort_values(by="거래금액(만원)", ascending=False).head(10)
# Out:
#                  시군구      번지     본번    부번         단지명   전용면적(㎡)    계약년월  계약일  \
# 28695  서울특별시 용산구 한남동     410  410.0   0.0       파르크한남  268.9500  202112   13
# 28694  서울특별시 용산구 한남동     410  410.0   0.0       파르크한남  268.6700  202111   26
# 28693  서울특별시 용산구 한남동     410  410.0   0.0       파르크한남  268.9500  202111   24
# 28692  서울특별시 용산구 한남동     410  410.0   0.0       파르크한남  268.6700  202109    9
# 28691  서울특별시 용산구 한남동     410  410.0   0.0       파르크한남  268.6700  202108    4
# 1582   서울특별시 강남구 청담동     129  129.0   0.0       PH129  273.9600  202107    7
# 28678  서울특별시 용산구 한남동     386  386.0   0.0    르가든더메인한남  228.3400  202109   15
# 1583   서울특별시 강남구 청담동     129  129.0   0.0       PH129  273.9600  202111   25
# 28671  서울특별시 용산구 한남동     829  829.0   0.0       나인원한남  244.3478  202112    2
# 1610   서울특별시 강남구 청담동  129-16  129.0  16.0  상지리츠빌카일룸3차  265.4700  202105   10
#
#        거래금액(만원)   층  건축년도          도로명     해제사유발생일  거래유형  중개사소재지
# ...

# %%
df = titanic
df.sort_values(by=['fare','age'], ascending=[False,True]).head()
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# 88          1       1  female  23.0      3      2  263.0000        S  First
#
#        who  adult_male deck  embark_town alive  alone
# 258  woman       False  NaN    Cherbourg   yes   True
# 737    man        True    B    Cherbourg   yes   True
# 679    man        True    B    Cherbourg   yes  False
# 27     man        True    C  Southampton    no  False
# 88   woman       False    C  Southampton   yes  False

# %%
seoul_apt.loc[0, "단지명"]
# Out:
# '개포2차현대아파트(220)'

# %%
seoul_apt.loc[0, :]   # 1개만 나오니깐 Series 형태
# Out:
# 시군구          서울특별시 강남구 개포동
# 번지                   655-2
# 본번                   655.0
# 부번                     2.0
# 단지명         개포2차현대아파트(220)
# 전용면적(㎡)              77.75
# 계약년월                202104
# 계약일                     15
# 거래금액(만원)            174000
# 층                        9
# 건축년도                  1988
# 도로명                언주로 103
# 해제사유발생일                NaN
# 거래유형                     -
# 중개사소재지                   -
# Name: 0, dtype: object

# %%
seoul_apt.loc[[0], :]     # [] list로 감싸주면 한개 행인데 dataframe으로 감싸진다.
# Out:
#              시군구     번지     본번   부번             단지명  전용면적(㎡)    계약년월  계약일  \
# 0  서울특별시 강남구 개포동  655-2  655.0  2.0  개포2차현대아파트(220)    77.75  202104   15
#
#    거래금액(만원)  층  건축년도      도로명  해제사유발생일 거래유형 중개사소재지
# 0    174000  9  1988  언주로 103      NaN    -      -

# %%
seoul_apt.loc[[0,10,100],:]
# Out:
#                시군구     번지      본번   부번             단지명  전용면적(㎡)    계약년월  계약일  \
# 0    서울특별시 강남구 개포동  655-2   655.0  2.0  개포2차현대아파트(220)   77.750  202104   15
# 10   서울특별시 강남구 개포동   1282  1282.0  0.0       개포래미안포레스트   49.920  202106   15
# 100  서울특별시 강남구 개포동   1280  1280.0  0.0        래미안블레스티지   59.967  202108   31
#
#      거래금액(만원)   층  건축년도      도로명  해제사유발생일 거래유형 중개사소재지
# 0      174000   9  1988  언주로 103      NaN    -      -
# 10     185000   6  2020  개포로 264      NaN    -      -
# 100    230000  12  2019    선릉로 8      NaN    -      -

# %%
seoul_apt.loc[:,["단지명","거래금액(만원)"]]
# Out:
#                   단지명  거래금액(만원)
# 0      개포2차현대아파트(220)    174000
# 1      개포6차우성아파트1동~8동    195000
# 2      개포6차우성아파트1동~8동    200000
# 3      개포6차우성아파트1동~8동    220000
# 4      개포6차우성아파트1동~8동    215000
# ...               ...       ...
# 32134  한신아파트(103~109)     83200
# 32135         한영(101)     50000
# 32136         한영(102)     49500
# 32137         한영(103)     30000
# 32138         한영(103)     61500
#
# [32139 rows x 2 columns]

# %%
titanic.loc[2:5, "class":"deck"]
# Out:
#    class    who  adult_male deck
# 2  Third  woman       False  NaN
# 3  First  woman       False    C
# 4  Third    man        True  NaN
# 5  Third    man        True  NaN

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# 타이타닉의 여성들의 나이를 구해라
b = titanic["sex"] == "female"
titanic.loc[b, "age"]
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 880    25.0
# 882    22.0
# 885    39.0
# 887    19.0
# 888     NaN
# Name: age, Length: 314, dtype: float64

# %%
# 생존한 여성들의 나이칼럼만 추출
b = (titanic["sex"] == "female") & (titanic["survived"] == 1)
titanic.loc[b, "age"]
# Out:
# 1      38.0
# 2      26.0
# 3      35.0
# 8      27.0
# 9      14.0
#        ...
# 874    28.0
# 875    15.0
# 879    56.0
# 880    25.0
# 887    19.0
# Name: age, Length: 233, dtype: float64

# %%
seoul_apt["시군구"].isin(["서울특별시 강남구 역삼동", "서울특별시 강남구 삼성동"]).sum()
# Out:
# 363
