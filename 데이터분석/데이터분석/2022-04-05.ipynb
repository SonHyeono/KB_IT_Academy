# %%
import pandas as pd

url="https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%ED%99%98%EC%9C%A8"
curr_list = pd.read_html(url)
print(len(curr_list))
# Out:
# 1

# %%
curr = curr_list[0]
curr
# Out:
#           통화명    매매기준율        전일대비     등락률
# 0      미국 USD  1212.40  전일대비하락3.60  -0.30%
# 1  일본 JPY 100   989.35  전일대비하락1.08  -0.11%
# 2    유럽연합 EUR  1330.00  전일대비하락8.15  -0.61%
# 3      중국 CNY   190.26  전일대비하락0.46  -0.24%
# 4      영국 GBP  1589.70  전일대비하락3.14  -0.20%
# 5      호주 AUD   914.03  전일대비상승0.94  +0.10%
# 6     캐나다 CAD   970.77  전일대비하락2.19  -0.23%
# 7    뉴질랜드 NZD   842.13  전일대비하락0.68  -0.08%

# %%
curr.loc[0,"통화명"]
# Out:
# '미국 USD'

# %%
curr.loc[0, '매매기준율']
# Out:
# 1212.4

# %%
import requests

url = "https://www.melon.com/chart/"

headers = {
    'User-Agent' : 'Mozilla/5.0'
}
req = requests.get(url, headers= headers)

melon_chart = pd.read_html( req.text )
len(melon_chart)
# Out:
# 1

# %%
melon_chart[0]
# Out:
#     Unnamed: 0    순위      순위등락  앨범이미지 곡 상세가기  \
# 0          NaN    1위  순위 동일  0    NaN    곡정보
# 1          NaN    2위  순위 동일  0    NaN    곡정보
# 2          NaN    3위  순위 동일  0    NaN    곡정보
# 3          NaN    4위  순위 동일  0    NaN    곡정보
# 4          NaN    5위  순위 동일  0    NaN    곡정보
# ..         ...   ...       ...    ...    ...
# 95         NaN   96위  단계 하락  1    NaN    곡정보
# 96         NaN   97위  순위 동일  0    NaN    곡정보
# 97         NaN   98위  순위 동일  0    NaN    곡정보
# 98         NaN   99위  순위 동일  0    NaN    곡정보
# 99         NaN  100위     순위 진입    NaN    곡정보
#
#                                      곡정보  \
# 0     봄여름가을겨울 (Still Life)  BIGBANG (빅뱅)
# 1                        TOMBOY  (여자)아이들
# 2      Feel My Rhythm  Red Velvet (레드벨벳)
# 3              GANADARA (Feat. 아이유)  박재범
# 4                           사랑인가 봐  멜로망스
# ..                                   ...
# 95            Off My Face  Justin Bieber
# 96              낙하 (with 아이유)  AKMU (악뮤)
# 97  어떻게 이별까지 사랑하겠어, 널 사랑하는 거지  AKMU (악뮤)
# 98             우리가 헤어져야 했던 이유  비비 (BIBI)
# 99                  아무래도 난  주시크 (Joosiq)
#
#                                            앨범          좋아요  듣기  담기    다운  \
# 0                        봄여름가을겨울 (Still Life)  좋아요  총건수  0  듣기  담기  다운로드
# 1                                 I NEVER DIE  좋아요  총건수  0  듣기  담기  다운로드
# 2   ‘The ReVe Festival 2022 - Feel My Rhythm’  좋아요  총건수  0  듣기  담기  다운로드
# 3                                    GANADARA  좋아요  총건수  0  듣기  담기  다운로드
# 4                    사랑인가 봐 (사내맞선 OST 스페셜 트랙)  좋아요  총건수  0  듣기  담기  다운로드
# ..                                        ...          ...  ..  ..   ...
# 95             Justice (The Complete Edition)  좋아요  총건수  0  듣기  담기  다운로드
# 96                               NEXT EPISODE  좋아요  총건수  0  듣기  담기  다운로드
# 97                                         항해  좋아요  총건수  0  듣기  담기  다운로드
# 98                         그 해 우리는 OST Part.2  좋아요  총건수  0  듣기  담기  다운로드
# 99                                     아무래도 난  좋아요  총건수  0  듣기  담기  다운로드
#
#        뮤비
# 0   뮤직비디오
# 1   뮤직비디오
# 2   뮤직비디오
# 3   뮤직비디오
# 4   뮤직비디오
# ..    ...
# 95  뮤직비디오
# 96  뮤직비디오
# 97  뮤직비디오
# 98  뮤직비디오
# 99  뮤직비디오
#
# [100 rows x 12 columns]

# %%
chart = melon_chart[0][["순위","곡정보","앨범"]]
chart
# Out:
#       순위                                   곡정보  \
# 0     1위    봄여름가을겨울 (Still Life)  BIGBANG (빅뱅)
# 1     2위                       TOMBOY  (여자)아이들
# 2     3위     Feel My Rhythm  Red Velvet (레드벨벳)
# 3     4위             GANADARA (Feat. 아이유)  박재범
# 4     5위                          사랑인가 봐  멜로망스
# ..   ...                                   ...
# 95   96위            Off My Face  Justin Bieber
# 96   97위              낙하 (with 아이유)  AKMU (악뮤)
# 97   98위  어떻게 이별까지 사랑하겠어, 널 사랑하는 거지  AKMU (악뮤)
# 98   99위             우리가 헤어져야 했던 이유  비비 (BIBI)
# 99  100위                  아무래도 난  주시크 (Joosiq)
#
#                                            앨범
# 0                        봄여름가을겨울 (Still Life)
# 1                                 I NEVER DIE
# 2   ‘The ReVe Festival 2022 - Feel My Rhythm’
# 3                                    GANADARA
# 4                    사랑인가 봐 (사내맞선 OST 스페셜 트랙)
# ..                                        ...
# 95             Justice (The Complete Edition)
# 96                               NEXT EPISODE
# 97                                         항해
# 98                         그 해 우리는 OST Part.2
# 99                                     아무래도 난
#
# [100 rows x 3 columns]

# %%
url="https://www.weatheri.co.kr/bygone/pastDB_tmp.php?jijum_id=108&start=2021-2-01&end=2021-12-30"
weather = pd.read_html( url )
len(weather)
# Out:
# 4

# %%
w = weather[3]
w.columns = w.loc[0,:]
w = w[["날짜","날씨"]]
w.drop(0,axis=0, inplace=True)
w
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# 0                 날짜         날씨
# 1   2021년 02월01일 (월)  구름많음/비/안개
# 2   2021년 02월02일 (화)       맑음/눈
# 3   2021년 02월03일 (수)     구름많음/눈
# 4   2021년 02월04일 (목)       맑음/눈
# 5   2021년 02월05일 (금)       구름많음
# 6   2021년 02월06일 (토)      흐림/안개
# 7   2021년 02월07일 (일)    구름조금/안개
# 8   2021년 02월08일 (월)         맑음
# 9   2021년 02월09일 (화)         맑음
# 10  2021년 02월10일 (수)    구름많음/안개
# 11  2021년 02월11일 (목)    구름많음/안개
# 12  2021년 02월12일 (금)    구름조금/안개
# 13  2021년 02월13일 (토)      맑음/안개
# 14  2021년 02월14일 (일)    흐림/비/안개
# 15  2021년 02월15일 (월)  구름많음/비/안개
# 16  2021년 02월16일 (화)     구름조금/눈
# 17  2021년 02월17일 (수)       맑음/눈
# 18  2021년 02월18일 (목)         맑음
# 19  2021년 02월19일 (금)       구름조금
# 20  2021년 02월20일 (토)    구름조금/안개
# 21  2021년 02월21일 (일)      맑음/안개
# 22  2021년 02월22일 (월)    구름조금/안개
# 23  2021년 02월23일 (화)       구름조금
# 24  2021년 02월24일 (수)       구름많음
# 25  2021년 02월25일 (목)       흐림/눈
# 26  2021년 02월26일 (금)       구름조금
# 27  2021년 02월27일 (토)       구름조금
# 28  2021년 02월28일 (일)       구름많음

# %%
w["날짜"].str[0:4] + w["날짜"].str[6:8] + w["날짜"].str[9:11]  # 제일 무식한 방법 apply를 이용하면 빠르게 처리 가능
# Out:
# 1     20210201
# 2     20210202
# 3     20210203
# 4     20210204
# 5     20210205
# 6     20210206
# 7     20210207
# 8     20210208
# 9     20210209
# 10    20210210
# 11    20210211
# 12    20210212
# 13    20210213
# 14    20210214
# 15    20210215
# 16    20210216
# 17    20210217
# 18    20210218
# 19    20210219
# 20    20210220
# 21    20210221
# 22    20210222
# 23    20210223
# 24    20210224
# 25    20210225
# 26    20210226
# 27    20210227
# 28    20210228
# Name: 날짜, dtype: object

# %%
def get_date(x):                           # 이렇게 하면 한번만 훑는 다
    return x[0:4] + x[6:8] + x[9:11] 
w["날짜"] = w["날짜"].apply(get_date)
w
# Out:
# C:\Users\user\AppData\Local\Temp/ipykernel_2568/215608030.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w["날짜"] = w["날짜"].apply(get_date)
# 0         날짜         날씨
# 1   20210201  구름많음/비/안개
# 2   20210202       맑음/눈
# 3   20210203     구름많음/눈
# 4   20210204       맑음/눈
# 5   20210205       구름많음
# 6   20210206      흐림/안개
# 7   20210207    구름조금/안개
# 8   20210208         맑음
# 9   20210209         맑음
# 10  20210210    구름많음/안개
# 11  20210211    구름많음/안개
# 12  20210212    구름조금/안개
# 13  20210213      맑음/안개
# 14  20210214    흐림/비/안개
# 15  20210215  구름많음/비/안개
# 16  20210216     구름조금/눈
# 17  20210217       맑음/눈
# 18  20210218         맑음
# 19  20210219       구름조금
# 20  20210220    구름조금/안개
# 21  20210221      맑음/안개
# 22  20210222    구름조금/안개
# 23  20210223       구름조금
# 24  20210224       구름많음
# 25  20210225       흐림/눈
# 26  20210226       구름조금
# 27  20210227       구름조금
# 28  20210228       구름많음

# %%
url="https://www.weatheri.co.kr/bygone/pastDB_tmp.php?jijum_id=108&start=2021-2-01&end=2021-12-30"
weather = pd.read_html( url )

w = weather[3]
w.columns = w.loc[0,:]
w = w[["날짜","날씨"]]
w.drop(0,axis=0, inplace=True)

def get_date(x):                           # 이렇게 하면 한번만 훑는 다
    return x[0:4] + x[6:8] + x[9:11] 
w["날짜"] = w["날짜"].apply(get_date)
w

# %%
for month in range(1,13):
    url=f"https://www.weatheri.co.kr/bygone/pastDB_tmp.php?jijum_id=108&start=2021-{month}-01&end=2021-12-30"
    weather = pd.read_html( url )

    w = weather[3]
    w.columns = w.loc[0,:]
    w = w[["날짜","날씨"]]
    w.drop(0, axis=0,inplace=True)

    def get_date(x):
        return x[0:4] + x[6:8] + x[9:11]

    w["날짜"] = w["날짜"].apply( get_date )
    display(w.head())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\user\AppData\Local\Temp/ipykernel_2568/697181460.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w["날짜"] = w["날짜"].apply( get_date )
# 0        날짜      날씨
# 1  20210101    구름조금
# 2  20210102      맑음
# 3  20210103    구름조금
# 4  20210104  구름조금/눈
# 5  20210105  구름조금/눈
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\user\AppData\Local\Temp/ipykernel_2568/697181460.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w["날짜"] = w["날짜"].apply( get_date )
# 0        날짜         날씨
# 1  20210201  구름많음/비/안개
# 2  20210202       맑음/눈
# 3  20210203     구름많음/눈
# 4  20210204       맑음/눈
# 5  20210205       구름많음
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\user\AppData\Local\Temp/ipykernel_2568/697181460.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w["날짜"] = w["날짜"].apply( get_date )
# 0        날짜           날씨
# 1  20210301  흐림/눈/비/진눈개비
# 2  20210302       구름많음/눈
# 3  20210303         구름조금
# 4  20210304         구름많음
# 5  20210305           맑음
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\user\AppData\Local\Temp/ipykernel_2568/697181460.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w["날짜"] = w["날짜"].apply( get_date )
# 0        날짜      날씨
# 1  20210401    구름많음
# 2  20210402    흐림/비
# 3  20210403    흐림/비
# 4  20210404  구름많음/비
# 5  20210405    구름조금
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\user\AppData\Local\Temp/ipykernel_2568/697181460.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w["날짜"] = w["날짜"].apply( get_date )
# 0        날짜       날씨
# 1  20210501  흐림/비/안개
# 2  20210502   구름조금/비
# 3  20210503     구름조금
# 4  20210504     흐림/비
# 5  20210505   구름조금/비
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\user\AppData\Local\Temp/ipykernel_2568/697181460.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w["날짜"] = w["날짜"].apply( get_date )
# 0        날짜         날씨
# 1  20210601  구름많음/비/안개
# 2  20210602    구름조금/안개
# 3  20210603       흐림/비
# 4  20210604       구름조금
# 5  20210605    구름조금/안개
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\user\AppData\Local\Temp/ipykernel_2568/697181460.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w["날짜"] = w["날짜"].apply( get_date )
# 0        날짜        날씨
# 1  20210701     맑음/안개
# 2  20210702      구름많음
# 3  20210703      흐림/비
# 4  20210704  흐림/비/이슬비
# 5  20210705        흐림
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\user\AppData\Local\Temp/ipykernel_2568/697181460.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w["날짜"] = w["날짜"].apply( get_date )
# 0        날짜        날씨
# 1  20210801      흐림/비
# 2  20210802      흐림/비
# 3  20210803  구름많음/소나기
# 4  20210804      구름많음
# 5  20210805      구름조금
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\user\AppData\Local\Temp/ipykernel_2568/697181460.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w["날짜"] = w["날짜"].apply( get_date )
# 0        날짜    날씨
# 1  20210901  흐림/비
# 2  20210902  구름많음
# 3  20210903    맑음
# 4  20210904  구름조금
# 5  20210905  구름많음
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\user\AppData\Local\Temp/ipykernel_2568/697181460.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w["날짜"] = w["날짜"].apply( get_date )
# 0        날짜           날씨
# 1  20211001  구름조금/천둥번개/비
# 2  20211002    구름조금/천둥번개
# 3  20211003        맑음/안개
# 4  20211004         흐림/비
# 5  20211005       구름많음/비
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\user\AppData\Local\Temp/ipykernel_2568/697181460.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w["날짜"] = w["날짜"].apply( get_date )
# 0        날짜       날씨
# 1  20211101  구름조금/안개
# 2  20211102  구름조금/안개
# 3  20211103     구름조금
# 4  20211104  맑음/비/안개
# 5  20211105    맑음/안개
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\user\AppData\Local\Temp/ipykernel_2568/697181460.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w["날짜"] = w["날짜"].apply( get_date )
# 0        날짜      날씨
# 1  20211201      맑음
# 2  20211202  구름조금/비
# 3  20211203    맑음/비
# 4  20211204      맑음
# 5  20211205      맑음

# %%
import time

# 날짜 별 날씨 저장용
weathers = []

for month in range(1,4):
    time.sleep(0.5)
    url=f"https://www.weatheri.co.kr/bygone/pastDB_tmp.php?jijum_id=108&start=2021-{month}-01&end=2021-12-30"
    print( url )

    weather = pd.read_html(url)
    w = weather[3]
    w.columns = w.loc[0,:]
    w = w[["날짜","날씨"]]
    w.drop(0, axis=0,inplace=True)

    def get_date(x):
        return x[0:4] + x[6:8] + x[9:11]

    w["날짜"] = w["날짜"].apply( get_date )
    display(w.head())
    weathers.append(w)
# Out:
# https://www.weatheri.co.kr/bygone/pastDB_tmp.php?jijum_id=108&start=2021-1-01&end=2021-12-30
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\user\AppData\Local\Temp/ipykernel_2568/1266898649.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w["날짜"] = w["날짜"].apply( get_date )
# 0        날짜      날씨
# 1  20210101    구름조금
# 2  20210102      맑음
# 3  20210103    구름조금
# 4  20210104  구름조금/눈
# 5  20210105  구름조금/눈
# https://www.weatheri.co.kr/bygone/pastDB_tmp.php?jijum_id=108&start=2021-2-01&end=2021-12-30
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\user\AppData\Local\Temp/ipykernel_2568/1266898649.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w["날짜"] = w["날짜"].apply( get_date )
# 0        날짜         날씨
# 1  20210201  구름많음/비/안개
# 2  20210202       맑음/눈
# 3  20210203     구름많음/눈
# 4  20210204       맑음/눈
# 5  20210205       구름많음
# https://www.weatheri.co.kr/bygone/pastDB_tmp.php?jijum_id=108&start=2021-3-01&end=2021-12-30
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\user\AppData\Local\Temp/ipykernel_2568/1266898649.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w["날짜"] = w["날짜"].apply( get_date )
# 0        날짜           날씨
# 1  20210301  흐림/눈/비/진눈개비
# 2  20210302       구름많음/눈
# 3  20210303         구름조금
# 4  20210304         구름많음
# 5  20210305           맑음

# %%
w_all = weathers[0]
for i in weathers[1:]:
    w_all = pd.concat([w_all,i], ignore_index=True)
    
display(w_all)
# Out:
# 0         날짜           날씨
# 0   20210101         구름조금
# 1   20210102           맑음
# 2   20210103         구름조금
# 3   20210104       구름조금/눈
# 4   20210105       구름조금/눈
# ..       ...          ...
# 85  20210327         흐림/비
# 86  20210328  흐림/비/안개/이슬비
# 87  20210329  구름많음/이슬비/황사
# 88  20210330        맑음/황사
# 89  20210331         구름조금
#
# [90 rows x 2 columns]

# %%
def get_weather_info(year, month=None):
    '''year, month의 날씨를 크롤링해서 반환.
    '''
    pass
    if month== None:
        start_month = 1
        end_month= 13
    else:
        start_month = month
        end_month = month +1

    import time

    # 날짜 별 날씨 저장용
    weathers = []

    for month in range(start_month,end_month):
        time.sleep(0.5)
        url=f"https://www.weatheri.co.kr/bygone/pastDB_tmp.php?jijum_id=108&start=2021-{month}-01&end=2021-12-30"
        print( url )

        weather = pd.read_html(url)
        w = weather[3]
        w.columns = w.loc[0,:]
        w = w[["날짜","날씨"]]
        w.drop(0, axis=0,inplace=True)

        def get_date(x):
            return x[0:4] + x[6:8] + x[9:11]

        w["날짜"] = w["날짜"].apply( get_date )
#         display(w.head())
        weathers.append(w)
    # 추출한 날씨를 하나로 합치기
        
    w_all = weathers[0]
    for i in weathers[1:]:
        w_all = pd.concat([w_all,i], ignore_index=True)
    
    return w_all

if __name__ == "__main__":
    # 테스트코드실행
    print(get_weather_info(2021,3))
# Out:
# https://www.weatheri.co.kr/bygone/pastDB_tmp.php?jijum_id=108&start=2021-3-01&end=2021-12-30
# 0         날짜           날씨
# 1   20210301  흐림/눈/비/진눈개비
# 2   20210302       구름많음/눈
# 3   20210303         구름조금
# 4   20210304         구름많음
# 5   20210305           맑음
# 6   20210306      구름조금/안개
# 7   20210307         구름조금
# 8   20210308           맑음
# 9   20210309      구름조금/안개
# 10  20210310        맑음/안개
# 11  20210311      구름많음/안개
# 12  20210312    구름많음/비/안개
# 13  20210313      구름많음/안개
# 14  20210314      구름조금/안개
# 15  20210315      흐림/비/안개
# 16  20210316   맑음/비/안개/황사
# 17  20210317        맑음/황사
# 18  20210318         구름많음
# 19  20210319         구름많음
# 20  20210320      흐림/비/안개
# 21  20210321    구름많음/비/안개
# 22  20210322           맑음
# 23  20210323        맑음/안개
# 24  20210324      구름조금/안개
# 25  20210325      구름조금/안개
# 26  20210326      구름많음/안개
# 27  20210327         흐림/비
# 28  20210328  흐림/비/안개/이슬비
# 29  20210329  구름많음/이슬비/황사
# 30  20210330        맑음/황사
# 31  20210331         구름조금
# C:\Users\user\AppData\Local\Temp/ipykernel_2568/2997116259.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   w["날짜"] = w["날짜"].apply( get_date )
